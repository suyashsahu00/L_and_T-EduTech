# %% [markdown]
# ## Intro to Attributes
# - An **attribute** is a piece of data that lives on an object.
# - An **attribute** is a fact, a detail, a characteristic of the object.
# - Access an attribute with `object.attribute` syntax.

# %%
import pandas as pd 
adjectives	= pd.Series( ["Smart",	"Handsome" ,	"Charming" ,	"Brilliant" ,	"Humble", "Smart"] )
adjectives
# Out:
# 0        Smart
# 1     Handsome
# 2     Charming
# 3    Brilliant
# 4       Humble
# 5        Smart
# dtype: object

# %%
adjectives.size
# Out:
# 6

# %%
adjectives.is_unique
# Out:
# False

# %%
adjectives.values
# Out:
# array(['Smart', 'Handsome', 'Charming', 'Brilliant', 'Humble', 'Smart'],
#       dtype=object)

# %%
adjectives.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
type(adjectives.values)
# Out:
# numpy.ndarray

# %%
type(adjectives.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# ## Parameters and Arguments
# - A **parameter** is the name for an expected input to a function/method/class instantiation.
# - An **argument** is the concrete value we provide for a parameter during invocation.

# %%
fruits = ["Apple", "Orange", "Plum", "Grape", "Blueberry", "Watermelon"]
weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Monday"]

# %%
pd.Series(fruits,weekdays)
# Out:
# Monday            Apple
# Tuesday          Orange
# Wednesday          Plum
# Thursday          Grape
# Friday        Blueberry
# Monday       Watermelon
# dtype: object

# %%
pd.Series(data=fruits, index=weekdays)
# Out:
# Monday            Apple
# Tuesday          Orange
# Wednesday          Plum
# Thursday          Grape
# Friday        Blueberry
# Monday       Watermelon
# dtype: object

# %% [markdown]
# ## Import Series with the pd.read_csv Function
# - A CSV is a plain text file that uses line breaks to separate rows and commas to separate row values.
# - Pandas ships with many different `read_` functions for different types of files.
# - The `read_csv` function accepts many different parameters. The first one specifies the file name/path.
# - The `read_csv` function will import the dataset as a **DataFrame**, a 2-dimensional table.
# - The `usecols` parameter accepts a list of the column(s) to import.
# - The `squeeze` method converts a **DataFrame** to a **Series.**

# %%
pd.read_csv("pokemon.csv")
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon =pd.read_csv("pokemon.csv", usecols=["Name"]).squeeze("columns")
pokemon
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
google =pd.read_csv("google_stock_price.csv",usecols=["Open"]).squeeze("columns")
google
# Out:
# 0         2.493464
# 1         2.518648
# 2         2.761511
# 3         2.773729
# 4         2.617140
#            ...
# 5154    183.220001
# 5155    184.320007
# 5156    185.059998
# 5157    185.600006
# 5158    184.070007
# Name: Open, Length: 5159, dtype: float64

# %% [markdown]
# ## The head and tail Methods
#
# - The `head` method returns a number of rows from the top/beginning of the `Series` .
# - The `tail` method returns a number of rows from the bottom/end of the `Series` .

# %%
pokemon = pd.read_csv("pokemon.csv",usecols=["Name"]).squeeze("columns")
google = pd.read_csv("google_stock_price.csv", usecols=["Open"]).squeeze("columns")

# %%
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
google.tail()
# Out:
# 5154    183.220001
# 5155    184.320007
# 5156    185.059998
# 5157    185.600006
# 5158    184.070007
# Name: Open, dtype: float64

# %% [markdown]
# ## Passing Series to Python's Built-In Functions
#
# - The `len` function returns the length of the **Series**.
# - The `type` function returns the type of an object.
# - The `list` function converts the **Series** to a list.
# - The `dict` function converts the **Series** to a dictionary.
# - The `sorted` function converts the **Series** to a sorted list.
# - The `max` function returns the largest value in the **Series**.
# - The `min` function returns the smalllest value in the **Series**.

# %%
pokemon = pd.read_csv("pokemon.csv",usecols=["Name"]).squeeze("columns")
google = pd.read_csv("google_stock_price.csv", usecols=["Open"]).squeeze("columns")

# %%
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
len(pokemon)
# Out:
# 800

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
list(pokemon)[:5]#list(pokemon)
# Out:
# ['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur', 'Charmander']

# %%
sorted(pokemon)[:5] #sorted(pokemon)
# Out:
# ['Abomasnow', 'AbomasnowMega Abomasnow', 'Abra', 'Absol', 'AbsolMega Absol']

# %%
sorted(google)[:5]
# Out:
# [2.4732664935985644,
#  2.4934637299363867,
#  2.511915070778778,
#  2.517151267959787,
#  2.518647456544224]

# %%
dict(pokemon)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'VenusaurMega Venusaur',
#  4: 'Charmander',
#  5: 'Charmeleon',
#  6: 'Charizard',
#  7: 'CharizardMega Charizard X',
#  8: 'CharizardMega Charizard Y',
#  9: 'Squirtle',
#  10: 'Wartortle',
#  11: 'Blastoise',
#  12: 'BlastoiseMega Blastoise',
#  13: 'Caterpie',
#  14: 'Metapod',
#  15: 'Butterfree',
#  16: 'Weedle',
#  17: 'Kakuna',
#  18: 'Beedrill',
#  19: 'BeedrillMega Beedrill',
#  20: 'Pidgey',
#  21: 'Pidgeotto',
#  22: 'Pidgeot',
#  23: 'PidgeotMega Pidgeot',
#  24: 'Rattata',
#  25: 'Raticate',
#  26: 'Spearow',
#  27: 'Fearow',
#  28: 'Ekans',
#  29: 'Arbok',
#  30: 'Pikachu',
#  31: 'Raichu',
#  32: 'Sandshrew',
#  33: 'Sandslash',
#  34: 'Nidoran♀',
#  35: 'Nidorina',
#  36: 'Nidoqueen',
#  37: 'Nidoran♂',
#  38: 'Nidorino',
#  39: 'Nidoking',
#  40: 'Clefairy',
#  41: 'Clefable',
#  42: 'Vulpix',
#  43: 'Ninetales',
#  44: 'Jigglypuff',
#  45: 'Wigglytuff',
#  46: 'Zubat',
#  47: 'Golbat',
#  48: 'Oddish',
# ...

# %%
max(google)
# Out:
# 203.38999938964844

# %%
min(google)
# Out:
# 2.4732664935985644

# %%
max(pokemon)
# Out:
# 'Zygarde50% Forme'

# %%
min(pokemon)
# Out:
# 'Abomasnow'

# %% [markdown]
# ## Check for Inclusion with Python's in Keyword
#
# - The `in` keyword checks if a value exists within an object.
# - The `in` keyword will look for a value in the **Series's** index.
# - Use the `index` and `values` attributes to access "nested" objects within the **Series's**.
# - Combine the `in` keyword with `values` to search within the **Series's** values.

# %%
pokemon = pd.read_csv("pokemon.csv",usecols=["Name"]).squeeze("columns")
google = pd.read_csv("google_stock_price.csv", usecols=["Open"]).squeeze("columns")

# %%
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
"Bulbasaur" in pokemon
# Out:
# False

# %%
0 in pokemon
# Out:
# True

# %%
pokemon.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
"Bulbasaur" in pokemon.values
# Out:
# True

# %% [markdown]
# ## The sort_values Method
#
# - The `sort_values` method sorts a **Series** values in order.
# - By default, pandas applies an ascending sort (smallest to largest).
# - Customize the sort order with the `ascending` parameter.

# %%
pokemon = pd.read_csv("pokemon.csv",usecols=["Name"]).squeeze("columns")
google = pd.read_csv("google_stock_price.csv", usecols=["Open"]).squeeze("columns")
google.head()
# Out:
# 0    2.493464
# 1    2.518648
# 2    2.761511
# 3    2.773729
# 4    2.617140
# Name: Open, dtype: float64

# %%
google.sort_values()
# Out:
# 10        2.473266
# 0         2.493464
# 13        2.511915
# 11        2.517151
# 12        2.518647
#            ...
# 5139    199.059998
# 5138    199.070007
# 5147    200.690002
# 5146    202.000000
# 5148    203.389999
# Name: Open, Length: 5159, dtype: float64

# %%
google.sort_values(ascending=False)
# Out:
# 5148    203.389999
# 5146    202.000000
# 5147    200.690002
# 5138    199.070007
# 5139    199.059998
#            ...
# 12        2.518647
# 11        2.517151
# 13        2.511915
# 0         2.493464
# 10        2.473266
# Name: Open, Length: 5159, dtype: float64

# %%
google.sort_values(ascending=False).head()
# Out:
# 5148    203.389999
# 5146    202.000000
# 5147    200.690002
# 5138    199.070007
# 5139    199.059998
# Name: Open, dtype: float64

# %% [markdown]
# ## The sort_index Method
#
# - The `sort_index` method sorts a **Series** by its index.
# - The `sort_index` method also accepts an `ascending` parameter to set sort order.

# %%
pd.read_csv("pokemon.csv",index_col="Name").squeeze("columns")
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pokemon.sort_index()
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# ## Extract Series Value by Index Position
#
# - Use the `iloc` accessor to extract a **Series** value by its index position.
# - `iloc` is short for "index location".
# - Python's list slicing syntaxes (slices, slices from start, slices to end, etc.) are supported with **Series** objects.

# %%
pd.read_csv("pokemon.csv",usecols=["Name"]).squeeze("columns")
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pokemon.iloc[0]
# Out:
# 'Bulbasaur'

# %%
pokemon.iloc[[100,200,300]]
# Out:
# 100      Haunter
# 200    Sudowoodo
# 300      Swellow
# Name: Name, dtype: object

# %%
pokemon.iloc[27:36]
# Out:
# 27       Fearow
# 28        Ekans
# 29        Arbok
# 30      Pikachu
# 31       Raichu
# 32    Sandshrew
# 33    Sandslash
# 34     Nidoran♀
# 35     Nidorina
# Name: Name, dtype: object

# %%
pokemon.iloc[0:6]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# 5               Charmeleon
# Name: Name, dtype: object

# %% [markdown]
# ## Extract Series Value by Index Label
#
# - Use the `loc` accessor to extract a **Series** value by its index label.
# - Pass a list to extract multiple values by index label.
# - If one index label/position in the list does not exist, Pandas will raise an error.

# %%
pd.read_csv("pokemon.csv",usecols=["Name"]).squeeze("columns")
pokemon.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Bulbasaur, Ivysaur, Venusaur, VenusaurMega Venusaur, Charmander]

# %%
pokemon = pd.read_csv("pokemon.csv", usecols=["Name"], index_col="Name").squeeze("columns")
pokemon.loc["Bulbasaur"]
# Out:
# Series([], Name: Bulbasaur, dtype: float64)

# %%
pokemon.loc["Bulbasaur"]
# Out:
# Series([], Name: Bulbasaur, dtype: float64)

# %%
pokemon[pokemon == "Bulbasaur"]
# Out:
# 0    Bulbasaur
# Name: Name, dtype: object

# %% [markdown]
# ## The get Method on a Series
#
# - The `get` method extracts a Series value by index label. It is an alternative option to square brackets.
# - The `get` method's second argument sets the fallback value to return if the label/position does not exist.

# %%
pokemon=pd.read_csv("pokemon.csv",index_col="Name").squeeze("columns")
pokemon.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
pokemon.get('Moltres')

# %%
pokemon.loc["Moltres"]
# Out:
# #                146
# Type 1          Fire
# Type 2        Flying
# Total            580
# HP                90
# Attack           100
# Defense           90
# Sp. Atk          125
# Sp. Def           85
# Speed             90
# Generation         1
# Legendary       True
# Name: Moltres, dtype: object

# %% [markdown]
# ## Overwrite a Series Value
# - Use the `ioc/ iloc` accessor to target an index label/position, then use an equal sign to provide a new value.

# %%
pokemon = pd.read_csv("pokemon.csv", usecols=["Name"]) .squeeze("columns")
pokemon. head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pokemon.iloc[0]="Borisaur" #inventing new pokemon at index 0 we have repelace the previsous with the new

# %%
pokemon.head()
# Out:
# 0                 Borisaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pokemon.iloc[[1,2,4]] = ["Firemon","Flammon","Blazemon"]

# %%
pokemon.head()
# Out:
# 0                 Borisaur
# 1                  Firemon
# 2                  Flammon
# 3    VenusaurMega Venusaur
# 4                 Blazemon
# Name: Name, dtype: object

# %%
pokemon = pd.read_csv("pokemon.csv", index_col="Name") .squeeze("columns")
pokemon. head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
pokemon.loc["Bulbasaur", "Name"] = "Awesomsor"

# %%
pokemon.head()
# Out:
#                        #     Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur              1  Awesomsor  Poison    318  45      49       49
# Ivysaur                2      Grass  Poison    405  60      62       63
# Venusaur               3      Grass  Poison    525  80      82       83
# VenusaurMega Venusaur  3      Grass  Poison    625  80     100      123
# Charmander             4       Fire     NaN    309  39      52       43
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# Name
# Bulbasaur                   65       65     45           1      False
# Ivysaur                     80       80     60           1      False
# Venusaur                   100      100     80           1      False
# VenusaurMega Venusaur      122      120     80           1      False
# Charmander                  60       50     65           1      False
#
#                             Name
# Name
# Bulbasaur              Awesomsor
# ...

# %% [markdown]
# ## The copy Method
#
# - A **copy** is a duplicate/replica of an object.
# - Changes to a copy do not modify the original object.
# - A **view** is a different way of looking at the same data.
# - Changes to a view do modify the original object.
# - The `copy` method creates a copy of a pandas object.

# %%
pokemon_df=pd.read_csv("pokemon.csv",usecols=["Name"])
pokemon_series = pokemon_df.squeeze("columns").copy()
# pokemon.head()

# %%
pokemon_df
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
pokemon_series
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon_series[0]
# Out:
# 'Bulbasaur'

# %%
pokemon_series[0]="Whatever"

# %%
pokemon_series.head()
# Out:
# 0                 Whatever
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pokemon_df #while making the copy there is no change in the original csv file(dataframe)
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %% [markdown]
# ## Math Methods on Series Objects
#
# - The `count` method returns the number of values in the **Series**. It excludes missing values; the size attribute includes missing values.
# - The `sum` method adds together the **Series**'s values.
# - The `product` method multiplies together the **Series's** values.
# - The `mean` method calculates the average of the **Series's** values.
# - The `std` method calculates the standard deviation of the **Series's** values.
# - The `max` method returns the largest value in the **Series**.
# - The `min` method returns the smallest value in the **Series**.
# - The `median` method returns the median of the **Series** (the value in the middle).
# - The `mode` method returns the mode of the **Series** (the most frequent value).
# - The `describe` method returns a summary with various mathematical calculations.

# %%
google = pd.read_csv("google_stock_price.csv", usecols=["Open"]).squeeze("columns")
google.head()
# Out:
# 0    2.493464
# 1    2.518648
# 2    2.761511
# 3    2.773729
# 4    2.617140
# Name: Open, dtype: float64

# %%
google.count() #exclude the missing values
# Out:
# np.int64(5159)

# %%
google.size #include the missing values
# Out:
# 5159

# %%
google.sum()
# Out:
# np.float64(250884.2474624056)

# %%
google.product()
# Out:
# C:\Users\suyas\anaconda3\Lib\site-packages\numpy\_core\_methods.py:55: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# np.float64(inf)

# %%
pd.Series([1,2,3]).product()
# Out:
# np.int64(6)

# %%
google.mean() #average
# Out:
# np.float64(48.63040268703345)

# %%
google.std() #Standard deviation measures how far data values typically spread out from the mean.
# Out:
# 47.210441769485506

# %%
google.max()
# Out:
# 203.38999938964844

# %%
google.min()
# Out:
# 2.4732664935985644

# %%
google.median()
# Out:
# 28.114083738931352

# %%
google.mode()
# Out:
# 0         2.473266
# 1         2.493464
# 2         2.511915
# 3         2.517151
# 4         2.518647
#            ...
# 5154    199.059998
# 5155    199.070007
# 5156    200.690002
# 5157    202.000000
# 5158    203.389999
# Name: Open, Length: 5159, dtype: float64

# %%
pd.Series([1,2,3,2,4]).mode()
# Out:
# 0    2
# dtype: int64

# %%
google.describe()
# Out:
# count    5159.000000
# mean       48.630403
# std        47.210442
# min         2.473266
# 25%        13.169726
# 50%        28.114084
# 75%        64.299166
# max       203.389999
# Name: Open, dtype: float64

# %% [markdown]
# ## Broadcasting
#
# - **Broadcasting** describes the process of applying an arithmetic operation to an array (i.e., a **Series**).
# - We can combine mathematical operators with a **Series** to apply the mathematical operation to every value.
# - There are also methods to accomplish the same results ( `add`, `sub`, `mul`, `div` , etc.)

# %%
google = pd.read_csv("google_stock_price.csv",usecols=["Open"]).squeeze("columns")
google.head()
# Out:
# 0    2.493464
# 1    2.518648
# 2    2.761511
# 3    2.773729
# 4    2.617140
# Name: Open, dtype: float64

# %%
google.add(10)
google + 10
# Out:
# 0        12.493464
# 1        12.518648
# 2        12.761511
# 3        12.773729
# 4        12.617140
#            ...
# 5154    193.220001
# 5155    194.320007
# 5156    195.059998
# 5157    195.600006
# 5158    194.070007
# Name: Open, Length: 5159, dtype: float64

# %%
google.sub(10)
# Out:
# 0        -7.506536
# 1        -7.481352
# 2        -7.238489
# 3        -7.226271
# 4        -7.382860
#            ...
# 5154    173.220001
# 5155    174.320007
# 5156    175.059998
# 5157    175.600006
# 5158    174.070007
# Name: Open, Length: 5159, dtype: float64

# %%
google -10
# Out:
# 0        -7.506536
# 1        -7.481352
# 2        -7.238489
# 3        -7.226271
# 4        -7.382860
#            ...
# 5154    173.220001
# 5155    174.320007
# 5156    175.059998
# 5157    175.600006
# 5158    174.070007
# Name: Open, Length: 5159, dtype: float64

# %%
google.mul(1.25)
# Out:
# 0         3.116830
# 1         3.148309
# 2         3.451889
# 3         3.467161
# 4         3.271425
#            ...
# 5154    229.025002
# 5155    230.400009
# 5156    231.324997
# 5157    232.000008
# 5158    230.087509
# Name: Open, Length: 5159, dtype: float64

# %%
google*1.25
# Out:
# 0         3.116830
# 1         3.148309
# 2         3.451889
# 3         3.467161
# 4         3.271425
#            ...
# 5154    229.025002
# 5155    230.400009
# 5156    231.324997
# 5157    232.000008
# 5158    230.087509
# Name: Open, Length: 5159, dtype: float64

# %% [markdown]
# ## The value_counts Method
# - The `value_counts` method returns the number of times each unique value occurs in the **Series**.
# - The `normalize` parameter returns the relative frequencies/percentages of the values instead of the counts.

# %%
pokemon = pd.read_csv("pokemon.csv",index_col="Name").squeeze("columns")
pokemon.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
df = pd.read_csv("pokemon.csv", index_col="Name",usecols=["Name", "Type 1"])
df.head()
# Out:
#                       Type 1
# Name
# Bulbasaur              Grass
# Ivysaur                Grass
# Venusaur               Grass
# VenusaurMega Venusaur  Grass
# Charmander              Fire

# %%
df.value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df.value_counts(ascending=True)
# Out:
# Type 1
# Flying        4
# Fairy        17
# Ice          24
# Fighting     27
# Steel        27
# Poison       28
# Dark         31
# Ghost        32
# Dragon       32
# Ground       32
# Electric     44
# Rock         44
# Fire         52
# Psychic      57
# Bug          69
# Grass        70
# Normal       98
# Water       112
# Name: count, dtype: int64

# %%
df.value_counts(normalize=True)
# Out:
# Type 1
# Water       0.14000
# Normal      0.12250
# Grass       0.08750
# Bug         0.08625
# Psychic     0.07125
# Fire        0.06500
# Electric    0.05500
# Rock        0.05500
# Ghost       0.04000
# Ground      0.04000
# Dragon      0.04000
# Dark        0.03875
# Poison      0.03500
# Fighting    0.03375
# Steel       0.03375
# Ice         0.03000
# Fairy       0.02125
# Flying      0.00500
# Name: proportion, dtype: float64

# %%
df.value_counts(normalize=True)*100
# Out:
# Type 1
# Water       14.000
# Normal      12.250
# Grass        8.750
# Bug          8.625
# Psychic      7.125
# Fire         6.500
# Electric     5.500
# Rock         5.500
# Ghost        4.000
# Ground       4.000
# Dragon       4.000
# Dark         3.875
# Poison       3.500
# Fighting     3.375
# Steel        3.375
# Ice          3.000
# Fairy        2.125
# Flying       0.500
# Name: proportion, dtype: float64

# %% [markdown]
# ## The apply Method
#
# - The `apply` method accepts a function. It invokes that function on every `Series` value.

# %%
pokemon = pd.read_csv("pokemon.csv",usecols=["Name"]).squeeze("columns")
pokemon.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
pokemon.apply(len)
# Out:
# 0       9
# 1       7
# 2       8
# 3      21
# 4      10
#        ..
# 795     7
# 796    19
# 797    19
# 798    18
# 799     9
# Name: Name, Length: 800, dtype: int64

# %%
def count_of_a(pokemon):
    return pokemon.count("a")
pokemon.apply(count_of_a)
# Out:
# 0      2
# 1      1
# 2      1
# 3      3
# 4      2
#       ..
# 795    1
# 796    3
# 797    2
# 798    2
# 799    1
# Name: Name, Length: 800, dtype: int64

# %% [markdown]
# ## The map Method
#
# - The `map` method "maps" or connects each **Series** values to another value.
# - We can pass the method a dictionary or a **Series**. Both types connects keys to values.
# - The `map` method uses our argument to connect or bridge together the values.

# %%
pokemon = pd.read_csv("pokemon.csv", index_col="Name",usecols=["Name", "Type 1"])
pokemon.head()
# Out:
#                       Type 1
# Name
# Bulbasaur              Grass
# Ivysaur                Grass
# Venusaur               Grass
# VenusaurMega Venusaur  Grass
# Charmander              Fire

# %%
attack_powers = {
    "Grass": 10,
    "Fire": 15,
    "Water": 15,
    "Fairy, Fighting": 20,
    "Grass, Psychic": 50
}

# %%
pokemon["Type 1"].map(attack_powers)
# Out:
# Name
# Bulbasaur                10.0
# Ivysaur                  10.0
# Venusaur                 10.0
# VenusaurMega Venusaur    10.0
# Charmander               15.0
#                          ...
# Diancie                   NaN
# DiancieMega Diancie       NaN
# HoopaHoopa Confined       NaN
# HoopaHoopa Unbound        NaN
# Volcanion                15.0
# Name: Type 1, Length: 800, dtype: float64

# %%
attack_powers = pd.Series({
    "Grass": 10,
    "Fire": 15,
    "Water": 15,
    "Fairy, Fighting": 20,
    "Grass, Psychic": 50
})
attack_powers.head()
# Out:
# Grass              10
# Fire               15
# Water              15
# Fairy, Fighting    20
# Grass, Psychic     50
# dtype: int64
